# %% [markdown]
# # Analyzing the Effect of Nutrition (Specifically Protein Content) on COVID-19 Cases Around the World

# %% [markdown]
# By: Justin Lu

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Source: Maria Ren on Kaggle
# * Nutritional data from the UN's Food and Agriculture Organization
# * Population data from the Population Reference Bureau
# * COVID-19 data from Johns Hopkins Center for Systems Science and Engineering

# %%
protein = pd.read_csv('Protein_Supply_Quantity_Data.csv')
protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetables  Miscellaneous  Obesity  \
# 0                   0.5824   3.1337  ...      1.1370         0.0462      4.5
# 1                   1.2757   7.6582  ...      3.2456         0.0544     22.3
# 2                   1.1624   3.5088  ...      3.1267         0.1399     26.6
# 3                   1.2754   7.6248  ...      0.8133         0.0924      6.8
# 4                   1.2586  16.0670  ...      1.6024         0.2947     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.065102  0.001238   0.012420  0.051443  38042000.0
# 1             6.2   0.053219  0.001260   0.036529  0.015430   2858000.0
# 2             3.9   0.025156  0.001767   0.017523  0.005866  43406000.0
# 3              25   0.000445  0.000019   0.000194  0.000232  31427000.0
# 4             NaN   0.026804  0.003093   0.020619  0.003093     97000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
protein.shape
# Out:
# (170, 32)

# %%
protein.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Miscellaneous', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Based on a cursory overview of the columns in our dataset, we can tell that most of these variables *could* be significant predictors of COVID-19 spread. The last column, `Unit (all except Population)`, is potentially less useful, as it is just an indication that the data we are working with are all in percentages.

# %%
protein = protein.drop(['Unit (all except Population)'], axis = 1)
protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  \
# 0                   0.5824   3.1337  ...          0.0000      1.1370
# 1                   1.2757   7.6582  ...          0.0084      3.2456
# 2                   1.1624   3.5088  ...          0.0269      3.1267
# 3                   1.2754   7.6248  ...          0.0092      0.8133
# 4                   1.2586  16.0670  ...          0.0430      1.6024
#
#    Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0         0.0462      4.5            29.8   0.065102  0.001238   0.012420
# 1         0.0544     22.3             6.2   0.053219  0.001260   0.036529
# 2         0.1399     26.6             3.9   0.025156  0.001767   0.017523
# 3         0.0924      6.8              25   0.000445  0.000019   0.000194
# 4         0.2947     19.1             NaN   0.026804  0.003093   0.020619
#
#      Active  Population
# 0  0.051443  38042000.0
# 1  0.015430   2858000.0
# 2  0.005866  43406000.0
# 3  0.000232  31427000.0
# 4  0.003093     97000.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Another area of cleaning that must be done is the presence of NaN (empty or missing) values in the dataset. The process of dealing with these missing values is known as **data imputation**. Now, we take a look at

# %%
protein.isna().sum()
# Out:
# Country                     0
# Alcoholic Beverages         0
# Animal Products             0
# Animal fats                 0
# Aquatic Products, Other     0
# Cereals - Excluding Beer    0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Offals                      0
# Oilcrops                    0
# Pulses                      0
# Spices                      0
# Starchy Roots               0
# Stimulants                  0
# Sugar Crops                 0
# Sugar & Sweeteners          0
# Treenuts                    0
# Vegetal Products            0
# Vegetable Oils              0
# Vegetables                  0
# Miscellaneous               0
# Obesity                     3
# Undernourished              7
# Confirmed                   9
# Deaths                      9
# Recovered                   9
# Active                      9
# Population                  0
# dtype: int64

# %% [markdown]
# There are many ways to go about imputing a missing value, but I chose to fill them with the average value of that specific column.
# We can see that some data pertaining to health in the countries, specifically the `Obesity` and `Undernourished` columns, are missing. For these two missing columns, I decided to impute with the average of the column. For the `Confirmed`, `Deaths`, `Recovered`, and `Active` columns, it was possible that data was unavailable/not provided. For example, it is difficult to obtain COVID data from North Korea, because their government probably would not provide it. It is also possible that (at the time that this data was obtained) some countries had not shown cases because there was no travel to or from that country. (We know now that every country on the planet has experienced cases of COVID-19.) Therefore, to keep things consistent, I opted to remove these countries from the analysis.

# %%
protein['Undernourished'] = protein['Undernourished'].replace({'<2.5': 2.5})
protein['Undernourished'] = np.array(protein['Undernourished']).astype(np.float)

# %%
protein['Obesity'] = protein['Obesity'].fillna(protein['Obesity'].mean())
protein['Undernourished'] = protein['Undernourished'].fillna(np.nanmean(protein['Undernourished']))

# %%
protein[protein['Confirmed'].isna() == True]
# Out:
#               Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 52   French Polynesia               0.3778          32.9981       0.2042
# 80           Kiribati               0.0338          24.9594       0.0473
# 81       Korea, North               0.0287          10.0832       0.0000
# 105           Myanmar               0.0161          23.9286       0.0911
# 109     New Caledonia               0.3262          29.1790       0.1873
# 131             Samoa               0.1866          30.9096       0.1341
# 139   Solomon Islands               0.1398          14.7782       0.0839
# 155      Turkmenistan               0.0000          21.5563       0.0485
# 164           Vanuatu               0.0078          19.8713       0.0863
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 52                    0.0153                   10.7050  1.1741         7.0448
# 80                    0.0000                   15.3680  0.4058        16.1052
# 81                    0.0000                   23.9070  1.3872         2.9561
# 105                   0.0000                   16.0006  0.8517         8.7797
# 109                   0.0181                   13.6531  1.6915         3.9207
# 131                   0.1341                    8.4665  0.4023         7.3761
# 139                   0.0186                   15.0205  0.3168         9.1129
# 155                   0.0000                   24.3242  1.1201         0.4685
# 164                   0.0000                   14.6387  0.6119         6.8016
#
#      Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  \
# 52                    0.3931  18.8677  ...          0.0153      1.2558
# 80                    0.9131   7.6502  ...          0.0000      1.3731
# 81                    0.6218   5.0990  ...          0.0000      4.6398
# 105                   0.4018  10.2743  ...          0.0000      1.8213
# 109                   0.6585  15.3749  ...          0.0362      1.7640
# 131                   1.6968  19.3878  ...          0.0058      0.5364
# 139                   0.5498   3.9415  ...          0.0000      0.4752
# 155                   0.4254  12.3586  ...          0.0162      1.8255
# 164                   1.1532   9.8533  ...          0.0078      1.5847
#
#      Miscellaneous    Obesity  Undernourished  Confirmed  Deaths  Recovered  \
# 52          1.1129  18.707784             4.2        NaN     NaN        NaN
# 80          0.1420  45.600000             2.7        NaN     NaN        NaN
# 81          0.0287   7.100000            47.8        NaN     NaN        NaN
# 105         0.0804   5.700000            10.6        NaN     NaN        NaN
# 109         1.1841  18.707784             7.1        NaN     NaN        NaN
# 131         0.3032  45.500000             2.7        NaN     NaN        NaN
# 139         0.2329  20.500000             8.9        NaN     NaN        NaN
# 155         0.0915  17.500000             5.4        NaN     NaN        NaN
# 164         0.1020  23.500000             7.2        NaN     NaN        NaN
#
#      Active  Population
# 52      NaN    279000.0
# 80      NaN    123000.0
# 81      NaN  25666000.0
# 105     NaN  54045000.0
# 109     NaN    291000.0
# 131     NaN    199000.0
# 139     NaN    699000.0
# 155     NaN   5942000.0
# 164     NaN    313000.0
#
# [9 rows x 31 columns]

# %%
protein = protein.drop(np.array(protein[protein['Confirmed'].isna() == True].index), axis = 0).reset_index(drop = True)

# %%
# cleaned dataset 
protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  \
# 0                   0.5824   3.1337  ...          0.0000      1.1370
# 1                   1.2757   7.6582  ...          0.0084      3.2456
# 2                   1.1624   3.5088  ...          0.0269      3.1267
# 3                   1.2754   7.6248  ...          0.0092      0.8133
# 4                   1.2586  16.0670  ...          0.0430      1.6024
#
#    Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  Recovered  \
# 0         0.0462      4.5       29.800000   0.065102  0.001238   0.012420
# 1         0.0544     22.3        6.200000   0.053219  0.001260   0.036529
# 2         0.1399     26.6        3.900000   0.025156  0.001767   0.017523
# 3         0.0924      6.8       25.000000   0.000445  0.000019   0.000194
# 4         0.2947     19.1       11.229448   0.026804  0.003093   0.020619
#
#      Active  Population
# 0  0.051443  38042000.0
# 1  0.015430   2858000.0
# 2  0.005866  43406000.0
# 3  0.000232  31427000.0
# 4  0.003093     97000.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Exploratory Data Analysis
#
# I want to extract some quick statistics and plots to better understand what the data distribution looks like.

# %%
protein['Population']
# Out:
# 0      38042000.0
# 1       2858000.0
# 2      43406000.0
# 3      31427000.0
# 4         97000.0
#           ...
# 156    28516000.0
# 157    95656000.0
# 158    29162000.0
# 159    17861000.0
# 160    14645000.0
# Name: Population, Length: 161, dtype: float64

# %%
top = protein[protein['Population'] > 100000000].sort_values(by = 'Confirmed', ascending = False)[:20]
top
# Out:
#                       Country  Alcoholic Beverages  Animal Products  \
# 153  United States of America               0.2946          32.4775
# 20                     Brazil               0.2807          29.0557
# 121        Russian Federation               0.3436          27.3905
# 97                     Mexico               0.2784          23.4422
# 112                  Pakistan               0.0000          21.0264
# 11                 Bangladesh               0.0000           9.9195
# 116               Philippines               0.1914          20.5089
# 67                      India               0.0077          11.2582
# 68                  Indonesia               0.0073          16.1640
# 75                      Japan               0.2541          27.7588
# 108                   Nigeria               0.4560           6.3757
# 30                      China               0.1648          30.6446
# 48                   Ethiopia               0.1676           4.4561
#
#      Animal fats  Aquatic Products, Other  Cereals - Excluding Beer    Eggs  \
# 153       0.0264                   0.0044                   10.4594  2.0048
# 20        0.1266                   0.0000                   12.1671  1.1831
# 121       0.0834                   0.0000                   16.2085  2.3071
# 97        0.0107                   0.0161                   19.3737  2.8587
# 112       0.0604                   0.0000                   20.8679  0.7472
# 11        0.0083                   0.0000                   31.7243  0.7216
# 116       0.3191                   0.0000                   23.2770  1.0211
# 67        0.0306                   0.0000                   25.2794  0.7271
# 68        0.0219                   0.0000                   27.3237  1.2821
# 75        0.0058                   0.0635                   12.4213  3.5687
# 108       0.0089                   0.0000                   24.4299  0.6349
# 30        0.0471                   0.0515                   10.8868  2.7059
# 48        0.0076                   0.0000                   29.7303  0.0990
#
#      Fish, Seafood  Fruits - Excluding Wine     Meat  ...  Vegetable Oils  \
# 153         2.3873                   0.5935  18.0875  ...          0.0835
# 20          1.3537                   0.7759  18.7486  ...          0.0220
# 121         3.2496                   0.4123  12.6006  ...          0.0245
# 97          2.3287                   0.9047  11.1188  ...          0.0214
# 112         0.4151                   0.2868   4.4830  ...          0.1132
# 11          5.8306                   0.3069   1.2773  ...          0.0000
# 116         6.6369                   1.2763   9.6682  ...          0.0000
# 67          1.5537                   0.6659   1.0179  ...          0.0000
# 68         10.1617                   0.7430   2.9210  ...          0.0000
# 75          9.5744                   0.3292   9.8112  ...          0.0289
# 108         2.3786                   0.7154   2.4323  ...          0.0000
# 30          5.9326                   0.4370  16.3074  ...          0.0059
# 48          0.1066                   0.1143   1.6834  ...          0.0000
#
#      Vegetables  Miscellaneous  Obesity  Undernourished  Confirmed    Deaths  \
# 153      1.3981         0.0000     37.3             2.5   0.636196  0.035161
# 20       0.8089         0.0000     22.3             2.5   0.414473  0.020700
# 121      1.6150         0.0442     25.7             2.5   0.360024  0.004728
# 97       1.2473         0.0054     28.4             3.6   0.116006  0.013542
# 112      0.9358         0.0226      7.8            20.3   0.066713  0.001260
# 11       1.2026         0.0249      3.4            14.7   0.053474  0.000715
# 116      1.9863         0.0558      6.0            13.3   0.023983  0.001006
# 67       2.3343         0.0000      3.8            14.5   0.023057  0.000661
# 68       1.2966         0.0073      6.9             8.3   0.014260  0.000795
# 75       1.9923         0.0635      4.4             2.5   0.013765  0.000735
# 108      2.5306         0.0268      7.8            13.4   0.008004  0.000209
# 30       3.6829         0.4679      6.6             8.5   0.006032  0.000332
# 48       0.4570         0.0076      3.6            20.6   0.002985  0.000051
#
#      Recovered    Active    Population
# 153   0.170685  0.409534  3.291530e+08
# 20    0.224113  0.169659  2.093320e+08
# 121   0.190509  0.164787  1.467310e+08
# 97    0.084769  0.017695  1.265770e+08
# 112   0.024806  0.040647  2.165650e+08
# 11    0.011444  0.041315  1.636670e+08
# 116   0.005507  0.017470  1.081170e+08
# 67    0.011666  0.010730  1.391885e+09
# 68    0.005414  0.008052  2.684190e+08
# 75    0.012295  0.000735  1.261800e+08
# 108   0.002597  0.005197  2.009640e+08
# 30    0.005685  0.000015  1.398030e+09
# 48    0.000486  0.002447  1.120790e+08
#
# [13 rows x 31 columns]

# %%
plt.figure(figsize=(15,12))
plt.title("Top COVID-19 Affected Countries (with populations over 100 million)")
ax = sns.barplot(x = top.Country, y = top.Confirmed)
suppress = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
protein.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Miscellaneous', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Population'],
#       dtype='object')

# %%
af = protein[protein['Country'] == 'Korea, South']
af[af.columns[1:23]].sum()
# Out:
# Alcoholic Beverages          1.0359
# Animal Products             25.3298
# Animal fats                  0.1804
# Aquatic Products, Other      1.0719
# Cereals - Excluding Beer    14.4764
# Eggs                         1.6698
# Fish, Seafood                8.3539
# Fruits - Excluding Wine      0.4741
# Meat                        11.4255
# Milk - Excluding Butter      1.6440
# Offals                       0.9843
# Oilcrops                     2.9221
# Pulses                       0.3504
# Spices                       0.0618
# Starchy Roots                0.3556
# Stimulants                   0.2268
# Sugar Crops                  0.0000
# Sugar & Sweeteners           0.0618
# Treenuts                     0.3762
# Vegetal Products            24.6702
# Vegetable Oils               0.0000
# Vegetables                   4.3290
# dtype: float64

# %%
protein['Vegetal Products'].values
# Out:
# array([40.2477, 22.2552, 36.1694, 34.7782, 16.8161, 18.0176, 27.1154,
#        17.0213, 19.9991, 33.7015, 15.8276, 40.0846, 21.7791, 22.9065,
#        21.5098, 31.0607, 38.8393, 27.3139, 31.6634, 29.71  , 20.9443,
#        25.012 , 42.8121, 31.4704, 35.3544, 41.8934, 24.8172, 28.1516,
#        34.5576, 24.3185, 19.3546, 24.3124, 26.1449, 21.921 , 38.4167,
#        20.2335, 31.5807, 21.5669, 19.2588, 17.6088, 40.3809, 22.7431,
#        24.3086, 27.2423, 37.5032, 32.6495, 21.401 , 35.2361, 45.5515,
#        28.8922, 18.7816, 18.9195, 25.6637, 37.0013, 31.5673, 19.7342,
#        37.8157, 23.0217, 19.6727, 34.595 , 40.7779, 39.4337, 27.8511,
#        40.012 , 32.6216, 21.6731, 14.2158, 38.7418, 33.836 , 35.5712,
#        38.8173, 21.4791, 20.436 , 23.2845, 25.3466, 22.2383, 32.5447,
#        21.0496, 37.3542, 24.6702, 26.2459, 29.7633, 37.9184, 21.4168,
#        35.0107, 40.4682, 37.7318, 19.2371, 18.2264, 39.2828, 41.5717,
#        22.6256, 19.9633, 36.3465, 21.2257, 31.5565, 28.1536, 26.5578,
#        15.9303, 19.6973, 36.0086, 41.2184, 31.6873, 41.4055, 17.2903,
#        21.4533, 33.3359, 42.3774, 43.6287, 29.5941, 20.7208, 25.2203,
#        28.9736, 23.4447, 26.6435, 31.1763, 29.4911, 23.1142, 18.241 ,
#        25.6886, 25.5201, 22.6095, 42.6148, 17.9799, 19.8161, 22.8894,
#        34.7935, 28.8594, 39.2692, 25.75  , 38.0747, 20.5789, 22.5062,
#        29.2848, 18.9394, 35.4541, 34.4307, 29.5006, 18.4582, 19.3974,
#        25.2362, 37.8554, 28.5363, 36.4432, 41.9749, 25.0443, 35.7583,
#        32.3339, 39.6046, 28.307 , 29.5822, 21.8944, 42.1845, 17.5247,
#        23.2856, 29.9781, 27.4545, 29.5617, 39.9831, 40.1117, 38.6508])

# %% [markdown]
# Extracting foods with high protein and coupled with data pertaining to health (obesity, undernourishment, etc.) trying to plot them in association with confirmed cases and seeing the relationship:
#
# animal products, eggs, fish/seafood, meat, treenuts, vegetal products, milk-excluding butter, obesity, undernourished

# %% [markdown]
# obesity and COVID: https://onlinelibrary.wiley.com/doi/10.1002/oby.22818
